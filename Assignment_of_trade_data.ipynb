# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
file_path = '/content/TRADES_CopyTr_90D_ROI.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#         Port_IDs                                      Trade_History  \
# 0    3.92537E+18  [{'time': 1718899656000, 'symbol': 'SOLUSDT', ...
# 1   set': 'USDT'                              'realizedProfit': 0.0
# 2    4.00241E+18  [{'time': 1718980078000, 'symbol': 'NEARUSDT',...
# 3  ity': 49.3168                            'quantityAsset': 'USDT'
# 4    3.92377E+18  [{'time': 1718677164000, 'symbol': 'ETHUSDT', ...
#
#                        Unnamed: 2                      Unnamed: 3  \
# 0                             NaN                             NaN
# 1   'realizedProfitAsset': 'USDT'              'baseAsset': 'FIL'
# 2                             NaN                             NaN
# 3           'realizedProfit': 0.0   'realizedProfitAsset': 'USDT'
# 4                             NaN                             NaN
#
#             Unnamed: 4               Unnamed: 5               Unnamed: 6  \
# 0                  NaN                      NaN                      NaN
# 1          'qty': 22.7   'positionSide': 'LONG'       'activeBuy': True}
# 2                  NaN                      NaN                      NaN
# 3   'baseAsset': 'JTO'              'qty': 16.0   'positionSide': 'BOTH'
# 4                  NaN                      NaN                      NaN
#
#                 Unnamed: 7               Unnamed: 8            Unnamed: 9  \
# 0                      NaN                      NaN                   NaN
# 1   {'time': 1718673344000      'symbol': 'FILUSDT'         'side': 'BUY'
# 2                      NaN                      NaN                   NaN
# 3       'activeBuy': True}   {'time': 1718221627000   'symbol': 'JTOUSDT'
# 4                      NaN                      NaN                   NaN
#
#    ...        Unnamed: 16374   Unnamed: 16375     Unnamed: 16376  \
# 0  ...                   NaN              NaN                NaN
# 1  ...   'symbol': 'SOLUSDT'   'side': 'SELL'   'price': 154.114
# 2  ...                   NaN              NaN                NaN
# 3  ...                   NaN              NaN                NaN
# 4  ...                   NaN              NaN                NaN
#
#       Unnamed: 16377       Unnamed: 16378        Unnamed: 16379  \
# 0                NaN                  NaN                   NaN
# 1   'fee': -0.077057   'feeAsset': 'USDT'   'quantity': 154.114
# 2                NaN                  NaN                   NaN
# 3                NaN                  NaN                   NaN
# 4                NaN                  NaN                   NaN
#
#              Unnamed: 16380          Unnamed: 16381  \
# 0                       NaN                     NaN
# 1   'quantityAsset': 'USDT'   'realizedProfit': 0.0
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
#
#                    Unnamed: 16382       Unnamed: 16383
# 0                             NaN                  NaN
# 1   'realizedProfitAsset': 'USDT'   'baseAsset': 'SOL'
# 2                             NaN                  NaN
# 3                             NaN                  NaN
# 4                             NaN                  NaN
#
# [5 rows x 16384 columns]

# %% [markdown]
# ### Data exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Columns: 16384 entries, Port_IDs to Unnamed: 16383
# dtypes: object(16384)
# memory usage: 33.9+ MB

# %%
df.describe()
# Out:
#             Port_IDs        Trade_History                      Unnamed: 2  \
# count            266                  270                             121
# unique           244                  219                              80
# top     set': 'USDT'   'feeAsset': 'USDT'   'realizedProfitAsset': 'USDT'
# freq               6                   10                              10
#
#                       Unnamed: 3           Unnamed: 4  \
# count                        121                  121
# unique                        65                   68
# top      'quantityAsset': 'USDT'   'feeAsset': 'USDT'
# freq                          10                   12
#
#                             Unnamed: 5                Unnamed: 6  \
# count                              121                       121
# unique                              78                        69
# top      'realizedProfitAsset': 'USDT'   'quantityAsset': 'USDT'
# freq                                10                        12
#
#                  Unnamed: 7                      Unnamed: 8  \
# count                   121                             121
# unique                   75                              72
# top      'feeAsset': 'USDT'   'realizedProfitAsset': 'USDT'
# freq                      9                              12
#
#                  Unnamed: 9  ...          Unnamed: 16374  \
# count                   121  ...                      44
# unique                   72  ...                      34
# top      'feeAsset': 'USDT'  ...   'realizedProfit': 0.0
# freq                     11  ...                       3
#
#                         Unnamed: 16375       Unnamed: 16376  \
# count                               44                   44
# unique                              33                   32
# top      'realizedProfitAsset': 'USDT'   'feeAsset': 'USDT'
# freq                                 4                    7
#
#              Unnamed: 16377            Unnamed: 16378  \
# count                    44                        44
# unique                   36                        26
# top      'feeAsset': 'USDT'   'quantityAsset': 'USDT'
# freq                      4                         7
#
#                   Unnamed: 16379                  Unnamed: 16380  \
# count                         44                              44
# unique                        32                              32
# top      'quantityAsset': 'USDT'   'realizedProfitAsset': 'USDT'
# freq                           4                               7
#
#                         Unnamed: 16381                  Unnamed: 16382  \
# count                               44                              44
# unique                              31                              33
# top      'realizedProfitAsset': 'USDT'   'realizedProfitAsset': 'USDT'
# freq                                 4                               4
#
#                   Unnamed: 16383
# count                         44
# unique                        29
# top      'quantityAsset': 'USDT'
# freq                           4
#
# [4 rows x 16384 columns]

# %%
# lets check any missing value
df.isnull().sum()
# Out:
# Port_IDs            5
# Trade_History       1
# Unnamed: 2        150
# Unnamed: 3        150
# Unnamed: 4        150
#                  ...
# Unnamed: 16379    227
# Unnamed: 16380    227
# Unnamed: 16381    227
# Unnamed: 16382    227
# Unnamed: 16383    227
# Length: 16384, dtype: int64

# %%
# lets remove all null values
df.dropna(inplace=True)

# %%
# lets check duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
# Feature Engineering - Calculating Financial Metrics
def calculate_metrics(df):
    account_metrics = []

    # Group by account (Port_IDs)
    grouped_df = df.groupby('Port_IDs')

    for account, group in grouped_df:
        # Check if 'realizedProfit' column exists for this account
        if 'realizedProfit' in group.columns:
            # Calculate ROI
            if 'quantityAsset' in group.columns: #Check if the column exists
                # Calculate ROI
                total_investment = group['quantityAsset'].sum()
                total_return = group['realizedProfit'].sum()
                roi = total_return / total_investment if total_investment != 0 else 0

                # Calculate PnL (Profit and Loss) - Use total_return only if it was calculated
                pnl = total_return
            else:
                # Handle cases where 'quantityAsset' column doesn't exist
                roi = 0 # or some other default value
                pnl = 0 # or some other default value

            # Calculate Win Rate and Win Positions
            win_positions = len(group[group['realizedProfit'] > 0])
            total_positions = len(group)
            win_rate = win_positions / total_positions if total_positions != 0 else 0

            # Calculate Sharpe Ratio
            daily_returns = group['realizedProfit']
            sharpe_ratio = (np.mean(daily_returns) / np.std(daily_returns)) if np.std(daily_returns) != 0 else 0

            # Calculate Maximum Drawdown (MDD)
            cumulative_returns = np.cumsum(group['realizedProfit'])
            running_max = np.maximum.accumulate(cumulative_returns)
            drawdown = (running_max - cumulative_returns) / running_max
            max_drawdown = np.max(drawdown) if len(drawdown) > 0 else 0

            # Store metrics for each account
            account_metrics.append({
                'Port_IDs': account,
                'ROI': roi,
                'PnL': pnl,
                'Sharpe Ratio': sharpe_ratio,
                'MDD': max_drawdown,
                'Win Rate': win_rate,
                'Win Positions': win_positions,
                'Total Positions': total_positions
              })
        else:
            # Handle cases where 'realizedProfit' doesn't exist for the account
            print(f"'realizedProfit' column not found for account: {account}")
            account_metrics.append({
                'Port_IDs': account,
                'ROI': 0,  # or some other default value
                'PnL': 0,  # or some other default value
                'Sharpe Ratio': 0,
                'MDD': 0,
                'Win Rate': 0,
                'Win Positions': 0,
                'Total Positions': 0
            })


    # Convert the results into a DataFrame
    metrics_df = pd.DataFrame(account_metrics)
    return metrics_df

# %%
metrics_df = calculate_metrics(df)
metrics_df.head()
# Out:
# 'realizedProfit' column not found for account:  'fee': -0.973245
# 'realizedProfit' column not found for account: ': 'LPT'
# 'realizedProfit' column not found for account: ': 'USDT'
# 'realizedProfit' column not found for account: ': 0.0121822
# 'realizedProfit' column not found for account: 'USDT'
# 'realizedProfit' column not found for account: 'activeBuy': True}
# 'realizedProfit' column not found for account: 'qty': 69.4
# 'realizedProfit' column not found for account: 0
# 'realizedProfit' column not found for account: 1.71888E+12
# 'realizedProfit' column not found for account: 10.851
# 'realizedProfit' column not found for account: 1000PEPE'
# 'realizedProfit' column not found for account: 20.068
# 'realizedProfit' column not found for account: 311575
# 'realizedProfit' column not found for account: 5126000
# 'realizedProfit' column not found for account: 956
# 'realizedProfit' column not found for account: : 'USDT'
# 'realizedProfit' column not found for account: : 0.7681621
# 'realizedProfit' column not found for account: : 1694.1574
# 'realizedProfit' column not found for account: : 562.66
# 'realizedProfit' column not found for account: Asset': 'USDT'
# 'realizedProfit' column not found for account: DT'
# 'realizedProfit' column not found for account: TH'
# 'realizedProfit' column not found for account: USDT'
# 'realizedProfit' column not found for account: UY'
# 'realizedProfit' column not found for account: Y'
# 'realizedProfit' column not found for account: dProfitAsset': 'USDT'
# 'realizedProfit' column not found for account: eBuy': True}
# 'realizedProfit' column not found for account: et': 'USDT'
# 'realizedProfit' column not found for account: ide': 'BOTH'
# 'realizedProfit' column not found for account: ime': 1718892411000
# 'realizedProfit' column not found for account: itionSide': 'BOTH'
# 'realizedProfit' column not found for account: ityAsset': 'USDT'
# 'realizedProfit' column not found for account: lizedProfitAsset': 'USDT'
# 'realizedProfit' column not found for account: mbol': 'BBUSDT'
# 'realizedProfit' column not found for account: ofit': 28.18642857
# 'realizedProfit' column not found for account: set': 'USDT'
# 'realizedProfit' column not found for account: sset': 'USDT'
# 'realizedProfit' column not found for account: t': 151.74144979
# 'realizedProfit' column not found for account: tityAsset': 'USDT'
#             Port_IDs  ROI  PnL  Sharpe Ratio  MDD  Win Rate  Win Positions  \
# 0   'fee': -0.973245    0    0             0    0         0              0
# 1           ': 'LPT'    0    0             0    0         0              0
# 2          ': 'USDT'    0    0             0    0         0              0
# 3       ': 0.0121822    0    0             0    0         0              0
# 4             'USDT'    0    0             0    0         0              0
#
#    Total Positions
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
# Ranking Algorithm
def rank_accounts(metrics_df):
    # Creating a weighted score (this can be adjusted as per preference)
    metrics_df['Score'] = (
        metrics_df['ROI'] * 0.3 +  # Assign weight to ROI
        metrics_df['PnL'] * 0.3 +  # Assign weight to PnL
        metrics_df['Sharpe Ratio'] * 0.2 +  # Assign weight to Sharpe Ratio
        metrics_df['Win Rate'] * 0.1 +  # Assign weight to Win Rate
        (1 - metrics_df['MDD']) * 0.1  # Penalize high drawdowns
    )

    # Sort accounts by the Score
    ranked_accounts = metrics_df.sort_values('Score', ascending=False)

    # Get the top 20 accounts
    top_20_accounts = ranked_accounts.head(20)
    return top_20_accounts

# %%
# Execute the functions and display results
def main():
    # Step 1: Data Exploration and Cleaning
    cleaned_df = explore_data(df)

    # Step 2: Feature Engineering - Calculating Financial Metrics
    metrics_df = calculate_metrics(cleaned_df)

    # Step 3: Ranking Algorithm
    top_20_accounts = rank_accounts(metrics_df)

    # Display the top 20 accounts
    print("Top 20 Accounts Based on Performance:")
    print(top_20_accounts)

# Run the main function
main()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40 entries, 1 to 261
# Columns: 16384 entries, Port_IDs to Unnamed: 16383
# dtypes: object(16384)
# memory usage: 5.0+ MB
# None
#        Port_IDs                   Trade_History  \
# count        40                              40
# unique       39                              30
# top           0   'realizedProfitAsset': 'USDT'
# freq          2                               4
#
#                             Unnamed: 2                Unnamed: 3  \
# count                               40                        40
# unique                              31                        30
# top      'realizedProfitAsset': 'USDT'   'quantityAsset': 'USDT'
# freq                                 4                         3
#
#                  Unnamed: 4           Unnamed: 5           Unnamed: 6  \
# count                    40                   40                   40
# unique                   30                   31                   34
# top      'activeBuy': True}   'feeAsset': 'USDT'   'activeBuy': True}
# freq                      3                    4                    2
#
#              Unnamed: 7       Unnamed: 8                      Unnamed: 9  ...  \
# count                40               40                              40  ...
# unique               29               33                              31  ...
# top      'side': 'SELL'   'side': 'SELL'   'realizedProfitAsset': 'USDT'  ...
# freq                  4                3                               4  ...
#
#                 Unnamed: 16374                  Unnamed: 16375  \
# count                       40                              40
# unique                      30                              31
# top      'realizedProfit': 0.0   'realizedProfitAsset': 'USDT'
# freq                         3                               4
#
#              Unnamed: 16376       Unnamed: 16377            Unnamed: 16378  \
# count                    40                   40                        40
# unique                   30                   33                        25
# top      'feeAsset': 'USDT'   'feeAsset': 'USDT'   'quantityAsset': 'USDT'
# freq                      6                    4                         6
#
#                   Unnamed: 16379                  Unnamed: 16380  \
# count                         40                              40
# unique                        31                              29
# top      'quantityAsset': 'USDT'   'realizedProfitAsset': 'USDT'
# freq                           4                               6
#
#                         Unnamed: 16381                  Unnamed: 16382  \
# count                               40                              40
# unique                              30                              30
# top      'realizedProfitAsset': 'USDT'   'realizedProfitAsset': 'USDT'
# freq                                 4                               4
#
#                   Unnamed: 16383
# count                         40
# unique                        29
# top      'quantityAsset': 'USDT'
# freq                           3
#
# [4 rows x 16384 columns]
#            Port_IDs           Trade_History                      Unnamed: 2  \
# 1      set': 'USDT'   'realizedProfit': 0.0   'realizedProfitAsset': 'USDT'
# 11  mbol': 'BBUSDT'          'side': 'SELL'                 'price': 0.3999
# 23    sset': 'USDT'      'baseAsset': 'FET'                    'qty': 651.0
# 25            USDT'      'quantity': 9.1704         'quantityAsset': 'USDT'
# 35              TH'      'activeBuy': True}          {'time': 1718971923000
#
#                   Unnamed: 3                      Unnamed: 4  \
# 1         'baseAsset': 'FIL'                     'qty': 22.7
# 11          'fee': -0.019995              'feeAsset': 'USDT'
# 23   'positionSide': 'SHORT'              'activeBuy': True}
# 25     'realizedProfit': 0.0   'realizedProfitAsset': 'USDT'
# 35       'symbol': 'APTUSDT'                   'side': 'BUY'
#
#                  Unnamed: 5                Unnamed: 6  \
# 1    'positionSide': 'LONG'        'activeBuy': True}
# 11        'quantity': 39.99   'quantityAsset': 'USDT'
# 23   {'time': 1718861412000       'symbol': 'FETUSDT'
# 25       'baseAsset': 'LDO'                'qty': 4.0
# 35           'price': 6.885         'fee': -0.0227205
#
#                        Unnamed: 7                      Unnamed: 8  \
# 1          {'time': 1718673344000             'symbol': 'FILUSDT'
# 11   'realizedProfit': 0.36348852   'realizedProfitAsset': 'USDT'
# 23                 'side': 'SELL'                  'price': 1.618
# 25        'positionSide': 'SHORT'             'activeBuy': False}
# 35             'feeAsset': 'USDT'              'quantity': 45.441
#
#                   Unnamed: 9  ...                  Unnamed: 16374  \
# 1              'side': 'BUY'  ...             'symbol': 'SOLUSDT'
# 11         'baseAsset': 'BB'  ...   'realizedProfitAsset': 'USDT'
# 23         'fee': -0.0220048  ...                 'price': 3778.0
# 25    {'time': 1718883115000  ...              'activeBuy': True}
# 35   'quantityAsset': 'USDT'  ...             'quantity': 36.6219
#
#               Unnamed: 16375                 Unnamed: 16376  \
# 1             'side': 'SELL'               'price': 154.114
# 11        'baseAsset': 'ENS'                     'qty': 4.3
# 23         'fee': -0.0219124             'feeAsset': 'USDT'
# 25    {'time': 1717557086000           'symbol': 'ORDIUSDT'
# 35   'quantityAsset': 'USDT'   'realizedProfit': 1.61285001
#
#                     Unnamed: 16377            Unnamed: 16378  \
# 1                 'fee': -0.077057        'feeAsset': 'USDT'
# 11          'positionSide': 'LONG'       'activeBuy': False}
# 23             'quantity': 109.562   'quantityAsset': 'USDT'
# 25                   'side': 'BUY'           'price': 53.468
# 35   'realizedProfitAsset': 'USDT'       'baseAsset': 'ORDI'
#
#                     Unnamed: 16379                  Unnamed: 16380  \
# 1              'quantity': 154.114         'quantityAsset': 'USDT'
# 11          {'time': 1718702703000             'symbol': 'ENSUSDT'
# 23   'realizedProfit': -0.03572412   'realizedProfitAsset': 'USDT'
# 25               'fee': -0.8661816              'feeAsset': 'USDT'
# 35                      'qty': 0.9          'positionSide': 'BOTH'
#
#             Unnamed: 16381                  Unnamed: 16382  \
# 1    'realizedProfit': 0.0   'realizedProfitAsset': 'USDT'
# 11          'side': 'SELL'                 'price': 22.733
# 23      'baseAsset': 'ETH'                    'qty': 0.029
# 25   'quantity': 1732.3632         'quantityAsset': 'USDT'
# 35      'activeBuy': True}          {'time': 1718890655000
#
#                    Unnamed: 16383
# 1              'baseAsset': 'SOL'
# 11             'fee': -0.00909319
# 23        'positionSide': 'SHORT'
# 25   'realizedProfit': -50.910419
# 35           'symbol': 'ORDIUSDT'
#
# [5 rows x 16384 columns]
# 'realizedProfit' column not found for account:  'fee': -0.973245
# 'realizedProfit' column not found for account: ': 'LPT'
# 'realizedProfit' column not found for account: ': 'USDT'
# 'realizedProfit' column not found for account: ': 0.0121822
# 'realizedProfit' column not found for account: 'USDT'
# 'realizedProfit' column not found for account: 'activeBuy': True}
# 'realizedProfit' column not found for account: 'qty': 69.4
# 'realizedProfit' column not found for account: 0
# 'realizedProfit' column not found for account: 1.71888E+12
# 'realizedProfit' column not found for account: 10.851
# 'realizedProfit' column not found for account: 1000PEPE'
# 'realizedProfit' column not found for account: 20.068
# 'realizedProfit' column not found for account: 311575
# 'realizedProfit' column not found for account: 5126000
# 'realizedProfit' column not found for account: 956
# 'realizedProfit' column not found for account: : 'USDT'
# 'realizedProfit' column not found for account: : 0.7681621
# 'realizedProfit' column not found for account: : 1694.1574
# 'realizedProfit' column not found for account: : 562.66
# 'realizedProfit' column not found for account: Asset': 'USDT'
# 'realizedProfit' column not found for account: DT'
# 'realizedProfit' column not found for account: TH'
# 'realizedProfit' column not found for account: USDT'
# 'realizedProfit' column not found for account: UY'
# 'realizedProfit' column not found for account: Y'
# 'realizedProfit' column not found for account: dProfitAsset': 'USDT'
# 'realizedProfit' column not found for account: eBuy': True}
# 'realizedProfit' column not found for account: et': 'USDT'
# 'realizedProfit' column not found for account: ide': 'BOTH'
# 'realizedProfit' column not found for account: ime': 1718892411000
# 'realizedProfit' column not found for account: itionSide': 'BOTH'
# 'realizedProfit' column not found for account: ityAsset': 'USDT'
# 'realizedProfit' column not found for account: lizedProfitAsset': 'USDT'
# 'realizedProfit' column not found for account: mbol': 'BBUSDT'
# 'realizedProfit' column not found for account: ofit': 28.18642857
# 'realizedProfit' column not found for account: set': 'USDT'
# 'realizedProfit' column not found for account: sset': 'USDT'
# 'realizedProfit' column not found for account: t': 151.74144979
# 'realizedProfit' column not found for account: tityAsset': 'USDT'
# Top 20 Accounts Based on Performance:
#                      Port_IDs  ROI  PnL  Sharpe Ratio  MDD  Win Rate  \
# 0            'fee': -0.973245    0    0             0    0         0
# 29        ime': 1718892411000    0    0             0    0         0
# 22                      USDT'    0    0             0    0         0
# 23                        UY'    0    0             0    0         0
# 24                         Y'    0    0             0    0         0
# 25      dProfitAsset': 'USDT'    0    0             0    0         0
# 26               eBuy': True}    0    0             0    0         0
# 27                et': 'USDT'    0    0             0    0         0
# 28               ide': 'BOTH'    0    0             0    0         0
# 30         itionSide': 'BOTH'    0    0             0    0         0
# 20                        DT'    0    0             0    0         0
# 31          ityAsset': 'USDT'    0    0             0    0         0
# 32  lizedProfitAsset': 'USDT'    0    0             0    0         0
# 33            mbol': 'BBUSDT'    0    0             0    0         0
# 34         ofit': 28.18642857    0    0             0    0         0
# 35               set': 'USDT'    0    0             0    0         0
# 36              sset': 'USDT'    0    0             0    0         0
# 37           t': 151.74144979    0    0             0    0         0
# 21                        TH'    0    0             0    0         0
# 19             Asset': 'USDT'    0    0             0    0         0
#
#     Win Positions  Total Positions  Score
# 0               0                0    0.1
# 29              0                0    0.1
# 22              0                0    0.1
# 23              0                0    0.1
# 24              0                0    0.1
# 25              0                0    0.1
# 26              0                0    0.1
# 27              0                0    0.1
# 28              0                0    0.1
# 30              0                0    0.1
# 20              0                0    0.1
# 31              0                0    0.1
# 32              0                0    0.1
# 33              0                0    0.1
# 34              0                0    0.1
# 35              0                0    0.1
# 36              0                0    0.1
# 37              0                0    0.1
# 21              0                0    0.1
# 19              0                0    0.1
